# %%
import os; cwd = os.getcwd()
if cwd.split('/')[-1]=='pips-design-toolkit': os.chdir('./tools')
from get_data_reduction_scores import main

# %%
main()
# Out:
# F is in MSA: False
# G is in MSA: False
# G is in MSA: False
# A is in MSA: False
# L is in MSA: False
# O is in MSA: False
# X is in MSA: False
# Saved fasta file to ../data/msa/GOh1052_msa_FGGALOX.fasta
# /Users/charmainechia/miniconda3/envs/pips-design-toolkit/lib/python3.11/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# Uploaded fasta msa.
# Clicked Submit.
# Obtained results.
# 2 ['1A', '0.95']
# 2 ['2S', '0.95']
# 2 ['3A', '0.95']
# 2 ['4P', '0.95']
# 2 ['5I', '0.92']
# 2 ['6G', '0.96']
# 2 ['7S', '0.96']
# 2 ['8A', '0.96']
# 2 ['9I', '0.96']
# 2 ['10P', '0.97']
# 2 ['11R', '0.98']
# 2 ['12N', '0.98']
# 2 ['13N', '0.97']
# 2 ['14W', '0.97']
# 2 ['15A', '0.98']
# 2 ['16V', '0.97']
# 2 ['17T', '0.98']
# 2 ['18C', '0.98']
# 2 ['19D', '0.98']
# 2 ['20S', '0.98']
# 2 ['21A', '0.98']
# 2 ['22Q', '0.97']
# 2 ['23S', '0.96']
# 2 ['24G', '0.96']
# ...
